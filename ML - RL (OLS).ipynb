# %%
#lINEAR REGRESSION 
#ORDINARY LEAST SQUARE
#(y=mx+b)
#taking ISLR DATA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\AcerWarrantyRegistration\\Course\\onlyPython\\ML for Python\\UNZIP_FOR_NOTEBOOKS_FINAL\\08-Linear-Regression-Models\\Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#we need only one column since we are using OLS simple one
df['Total_spend'] = df['TV'] + df['radio'] + df['newspaper']

# %%
df
# Out:
#         TV  radio  newspaper  sales  Total_spend
# 0    230.1   37.8       69.2   22.1        337.1
# 1     44.5   39.3       45.1   10.4        128.9
# 2     17.2   45.9       69.3    9.3        132.4
# 3    151.5   41.3       58.5   18.5        251.3
# 4    180.8   10.8       58.4   12.9        250.0
# ..     ...    ...        ...    ...          ...
# 195   38.2    3.7       13.8    7.6         55.7
# 196   94.2    4.9        8.1    9.7        107.2
# 197  177.0    9.3        6.4   12.8        192.7
# 198  283.6   42.0       66.2   25.5        391.8
# 199  232.1    8.6        8.7   13.4        249.4
#
# [200 rows x 5 columns]

# %%
plt.figure(dpi=300)
sns.scatterplot(data=df,x='Total_spend',y='sales')
# Out:
# <Axes: xlabel='Total_spend', ylabel='sales'>

# %%
plt.figure(dpi=300)
sns.regplot(data=df,x='Total_spend',y='sales')
# Out:
# <Axes: xlabel='Total_spend', ylabel='sales'>

# %%
X = df['Total_spend']
y = df['sales']

# %%
np.polyfit(X,y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potentional_spend = np.linspace(0,500,100)

# %%
predicted_sales = 0.04868788 *potentional_spend + 4.24302822

# %%
sns.scatterplot(x='Total_spend',y='sales',data=df)
plt.plot(potentional_spend,predicted_sales,color='red')

# %%
spend = 200
predicted_sales = 0.04868788 *spend + 4.24302822

# %%
predicted_sales
# Out:
# 13.98060422

# %%
np.polyfit(X,y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
pot_spend = np.linspace(0,500,100)

# %%
pred_Sales  = (3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2 +8.20886302e-02*pot_spend)

# %%
sns.scatterplot(x='Total_spend',y='sales',data=df)
plt.plot(potentional_spend,pred_Sales,color='red')

# %%
#model traininig 
#ski-kit learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfski = pd.read_csv('C:\\AcerWarrantyRegistration\\Course\\onlyPython\\ML for Python\\UNZIP_FOR_NOTEBOOKS_FINAL\\08-Linear-Regression-Models\\Advertising.csv')

# %%
dfski.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.pairplot(dfski)

# %%
X=dfski.drop('sales',axis=1)

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
Y = dfski['sales']

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\gokul\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , x_test , y_train , y_test = train_test_split(X , y, test_size = 0.3 , random_state = 101)

# %%
y_train
# Out:
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
#        ...
# 63     14.0
# 70     18.3
# 81     12.3
# 11     17.4
# 95     16.9
# Name: sales, Length: 140, dtype: float64

# %%
X_train
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
#Performance Evaluation
#Mean Absolute Error - Easiest
#Mean squared error
#Root mean squared error

# %%
test_predictions = model.predict(x_test) #y_test

# %%
test_predictions
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
df['sales'].mean()
# Out:
# 14.0225

# %%
sns.histplot(data=dfski,x='sales',bins=20)
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
mean_absolute_error(y_test,test_predictions)
# Out:
# 1.213745773614481

# %%
mean_absolute_error(y_test,test_predictions)
# Out:
# 1.213745773614481

# %%
np.sqrt(mean_absolute_error(y_test,test_predictions))
# Out:
# 1.1017013087105239

# %%
np.sqrt(mean_squared_error(y_test,test_predictions))
# Out:
# 1.516151937599388

# %%
test_residuals = y_test - test_predictions

# %%
test_residuals
# Out:
# 37    -1.041313
# 109    0.189374
# 31     0.451111
# 89    -0.308198
# 66     0.327143
# 119   -0.412483
# 54    -0.089925
# 74    -0.299540
# 145    0.524155
# 142    0.878058
# 148   -1.505032
# 112    0.207650
# 174   -2.225411
# 55     2.412060
# 141    0.775434
# 149    0.118016
# 25    -3.552290
# 34     1.810863
# 170    0.843850
# 39     1.096888
# 172   -0.192152
# 153    0.757859
# 175    2.313681
# 61     1.378009
# 65     1.320379
# 50    -1.252073
# 42    -0.769259
# 129    1.647714
# 179    0.176840
# 2     -3.207197
# 12    -1.577578
# 133    0.355399
# 90     1.129731
# 22    -1.107800
# 41    -0.214921
# 32     1.832357
# 125    1.346067
# 196    1.421653
# 158   -3.281056
# 180   -0.135911
# 16    -0.510026
# 186    0.528079
# 144    1.185301
# 121   -1.045720
# 80     0.232893
# 18     1.216320
# 78    -3.698066
# 48    -1.453889
# 4     -0.339423
# 15     1.585066
# 1     -2.097274
# 43    -1.066159
# 102   -2.762851
# 164    0.754630
# 9     -1.962615
# ...

# %%
sns.scatterplot(x=y_test,y=test_residuals)
plt.axhline(y=0,color='r')

# %%
sns.displot(test_residuals,bins=30,kde=True)

# %%
import scipy as sp

# %%
fig , ax  = plt.subplots(figsize=(6,8),dpi=250)
_ = sp.stats.probplot(test_residuals,plot=ax)

# %%
final_model = LinearRegression()

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
y_hat = final_model.predict(X)

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))
axes[0].plot(df['TV'],df['sales'],'o')
axes[0].plot(df['TV'],y_hat,'o',color='red')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['radio'],df['sales'],'o')
axes[1].plot(df['radio'],y_hat,'o',color='red')
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")


axes[2].plot(df['newspaper'],df['sales'],'o')
axes[2].plot(df['newspaper'],y_hat,'o',color='red')
axes[2].set_ylabel("Sales")
axes[2].set_title("Newspaper Spend")
plt.tight_layout();

# %%
from joblib import dump,load

# %%
dump(final_model,'final_sales_model.joblib')
# Out:
# ['final_sales_model.joblib']

# %%
loaded_model = load('final_sales_model.joblib')

# %%
loaded_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.shape
# Out:
# (200, 3)

# %%
#149 TV  22RADIO 12 NEWS
campaign = [[149,22,13]]

# %%
loaded_model.predict(campaign)
# Out:
# C:\Users\gokul\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.8919945])

# %%
#POLYNOMIAL REGRESSION

# %%
dfpoly = pd.read_csv('C:\\AcerWarrantyRegistration\\Course\\onlyPython\\ML for Python\\UNZIP_FOR_NOTEBOOKS_FINAL\\08-Linear-Regression-Models\\Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  Total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
X=dfpoly.drop('sales',axis=1)

# %%
y = dfpoly['sales']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_features = PolynomialFeatures(degree=2,include_bias=False)

# %%
polynomial_features.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_features.transform(X)

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
X.shape
# Out:
# (200, 3)

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
polynomial_features.fit_transform(X)
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test , y_train , y_test = train_test_split(poly_features,y,test_size=0.33,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mae = mean_absolute_error(y_test,test_predictions)

# %%
MSE = mean_squared_error(y_test,test_predictions)

# %%
RMSE =np.sqrt(mean_squared_error(y_test,test_predictions))

# %%
mae
# Out:
# 0.48428105352155065

# %%
RMSE
# Out:
# 0.6482912032533593

# %%
model.coef_
# Out:
# array([ 5.25319441e-02,  1.42773271e-02,  1.47528851e-02, -1.12739168e-04,
#         1.13231490e-03, -5.42180033e-05,  6.26813126e-05,  8.93347558e-05,
#        -3.52004070e-05])

# %%
#OVERFITTING UNDERFITTING
